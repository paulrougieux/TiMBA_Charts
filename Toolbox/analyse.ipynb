# %% [markdown]
# ### Import neccassary packages

# %%
import pandas as pd
import numpy as np
from classes.import_data import package_directory, parameters
from classes.import_data import import_pkl_data
from classes.scenario_plots import sc_plot, PlotDropDown, HeatmapDropDown, InteractivePrice, interactiveModelComparison
from classes.model_analysis import validation
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### Identify the actual path of this jupyter file

# %%
PACKAGEDIR = package_directory()
print(PACKAGEDIR)
# Out:
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox

# %% [markdown]
# ### Import data

# %%
import_pkl = import_pkl_data()
data = import_pkl.combined_data()
data_model_intercomparison = {}
try:
    data_model_intercomparison['Carbon'] = data['Carbon']
    data_model_intercomparison['WorldPrices'] = data['WorldPrices']
    data_model_intercomparison['Forest'] = data['Forest']
    data_model_intercomparison['Data'] = data['data_periods']
except KeyError:
    pass
#data = data["data_periods"]
# Out:
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\Archive
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\DataContainer_Sc_baseline_ssp2.pkl
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\DataContainer_Sc_baseline_ssp2_start2023.pkl
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\DataContainer_Sc_baseline_ssp2_start2023_mafg.pkl

# %% [markdown]
# ### Plot predefined scenario results

# %%
sc_plot = sc_plot()
sc_plot.predefined_plot(data["data_periods"])

# %% [markdown]
# ### Interactive scenario results (quantities) Nr. 1: basic one year simulation

# %%
data_periods = data["data_periods"]
PlotDropDown(data=data_periods,
             unique_color=False, #one color for all GFPMpt scenarios
             color='darkblue', #choose color for GFPMpt scenarios
             legend=True, #add legend to plot
             start=1990, #starting year for the plot
             end=2050, #ending year for the plot
             scenario_range=False) #plot only the minimum, maximum and mean of all GFPMpt scenarios
# Out:
# interactive(children=(Dropdown(description='Select RegionCode:', options=('Alle', 'a0', 'a1', 'a2', 'a3', 'a4'…

# %% [markdown]
# ### Interactive scenario results (quantities) Nr. 2: Demand and supply (plus one) elasticities from Morland et al. 2018, one year simulation

# %%
data_periods = data["data_periods"]
plot_dropdown_instance = PlotDropDown(data=data_periods,
                                      unique_color=True, #one color for all GFPMpt scenarios
                                      color='darkgreen', #choose color for GFPMpt scenarios
                                      legend=False, #add legend to plot
                                      start=1990, #starting year for the plot
                                      end=2030, #ending year for the plot
                                      scenario_range=False) #plot only the minimum, maximum and mean of all GFPMpt scenarios
# Out:
# interactive(children=(Dropdown(description='Select RegionCode:', options=('Alle', 'a0', 'a1', 'a2', 'a3', 'a4'…

# %% [markdown]
# ### Interactive scenario results (quantities) Nr. 3: Demand_Elasticities_Morland_et_al_2018, one year

# %%
data_periods = data["data_periods"]
plot_dropdown_instance = PlotDropDown(data=data_periods,
                                      unique_color=True, #one color for all GFPMpt scenarios
                                      color='darkviolet', #choose color for GFPMpt scenarios
                                      legend=False, #add legend to plot
                                      start=1990, #starting year for the plot
                                      end=2030, #ending year for the plot
                                      scenario_range=False) #plot only the minimum, maximum and mean of all GFPMpt scenarios
# Out:
# interactive(children=(Dropdown(description='Select RegionCode:', options=('Alle', 'a0', 'a1', 'a2', 'a3', 'a4'…

# %% [markdown]
# ### Interactive scenario results (quantities) Nr. 4: Demand and Supply Elasticities from Morland et al. 2018, one year simulation

# %%
data_periods = data["data_periods"]
plot_dropdown_instance = PlotDropDown(data=data_periods,
                                      unique_color=True, #one color for all GFPMpt scenarios
                                      color='darkred', #choose color for GFPMpt scenarios
                                      legend=False, #add legend to plot
                                      start=1990, #starting year for the plot
                                      end=2030, #ending year for the plot
                                      scenario_range=False) #plot only the minimum, maximum and mean of all GFPMpt scenarios
# Out:
# interactive(children=(Dropdown(description='Select RegionCode:', options=('Alle', 'a0', 'a1', 'a2', 'a3', 'a4'…

# %% [markdown]
# ### Interactive scenario results (quantities) Nr. 5: Demand Elasticities from Morland et al. 2018, Test with Supply Elasticities, one year simulation

# %%
data_periods = data["data_periods"]
plot_dropdown_instance = PlotDropDown(data=data_periods,
                                      unique_color=False, #one color for all GFPMpt scenarios
                                      color='darkviolet', #choose color for GFPMpt scenarios
                                      legend=True, #add legend to plot
                                      start=1990, #starting year for the plot
                                      end=2030, #ending year for the plot
                                      scenario_range=False) #plot only the minimum, maximum and mean of all GFPMpt scenarios
# Out:
# interactive(children=(Dropdown(description='Select RegionCode:', options=('Alle', 'a0', 'a1', 'a2', 'a3', 'a4'…

# %% [markdown]
# ### Validation tables

# %%
validation = validation()
data_vali = validation.model_difference(data=data["data_periods"])
data_quantities = validation.model_corrcoef(data["data_periods"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24424/3202444423.py in <module>
#       1 validation = validation()
# ----> 2 data_vali = validation.model_difference(data=data["data_periods"])
#       3 data_quantities = validation.model_corrcoef(data["data_periods"])
#
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\classes\model_analysis.py in model_difference(self, data)
#      24
#      25     def model_difference(self, data: pd.DataFrame):
# ---> 26         data_gfpm = data[data.ID==0].reset_index(drop=True)
#      27         data_gfpm = data_gfpm[['RegionCode','domain',"CommodityCode","quantity"]]
#      28         for i in data.ID.unique():
#
# c:\Python397\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ID'

# %% [markdown]
# ### Interactive scenario results (prices)

# %%
#price_interactive = InteractivePrice(data["data_periods"])

# %% [markdown]
# ### Forest Plots

# %%
import_pkl = import_pkl_data()
data = import_pkl.combined_data()
forest_data = data['Forest']
country_data = import_pkl.read_country_data()
forest_data_world = import_pkl.read_forest_data_gfpm(country_data=country_data)
forest_data = forest_data[forest_data_world.columns]
forest_data = pd.concat([forest_data, forest_data_world], axis= 0)


import matplotlib.pyplot as plt
class ForestData:
    def __init__(self, data):
        self.data = forest_data


    def drop_duplicates(self):
        self.data = self.data.drop_duplicates().reset_index(drop=True)



    def plot_stock_area_diagrams(self):
        scenarios = self.data['Scenario'].unique()
        total_periods = self.data['Period'].unique()


        plt.figure(figsize=(12, 6))
        bar_width = 0.05
        bar_gap = -0.42
        for i, scenario in enumerate(scenarios):
            scenario_name = self.data[self.data['Scenario'] == scenario]
            total_stock = scenario_name.groupby('Period')['ForStock'].sum()


            
            periods_runner = total_stock.index.intersection(total_periods)
            bar_positions = np.arange(len(periods_runner)) + i * (len(periods_runner) * bar_width + bar_gap)
            plt.bar(bar_positions, total_stock[periods_runner], label=f'{scenario} (ForStock)', width=bar_width, align='edge')


        #plt.ylim(ymin=3e6)
        plt.xlabel('Period')
        plt.ylabel('Sum of ForStock')
        plt.legend()
        plt.title('ForStock')
        plt.show()


        plt.figure(figsize=(12, 6))
        for i, scenario in enumerate(scenarios):
            scenario_name = self.data[self.data['Scenario'] == scenario]
            total_area = scenario_name.groupby('Period')['ForArea'].sum()


         
            periods_runner = total_area.index.intersection(total_periods)
            bar_positions = np.arange(len(periods_runner)) + i * (len(periods_runner) * bar_width + bar_gap)
            plt.bar(bar_positions, total_area[periods_runner], label=f'{scenario} (ForArea)', width=bar_width)


        #plt.ylim(ymin=3e7)
        plt.xlabel('Period')
        plt.ylabel('Sum of ForArea')
        plt.legend(loc = 'lower right')
        plt.title('ForArea')
        plt.show()



data_container = data
forest_plot = ForestData(data_container)
forest_plot.drop_duplicates()
forest_plot.plot_stock_area_diagrams()
# Out:
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\Archive
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\DataContainer_Sc_baseline_ssp2.pkl
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\DataContainer_Sc_baseline_ssp2_start2023.pkl
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\Input\Scenario_Files\DataContainer_Sc_baseline_ssp2_start2023_mafg.pkl
# e:\P_TiMBA\Analyses_Toolbox_TiMBA_workshop\Toolbox\classes\import_data.py:236: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forest_gfpm[parameters.column_name_scenario.value]= 'world500'

# %% [markdown]
# ### Validation model intercomparision

# %%
#Model intercomprison
country_data = validation.readin_country_data()
external_model_data = validation.readin_external_data()
data_filtered = validation.filter_data(data=data_model_intercomparison, country_data=country_data)

# reformate external_model_data
external_model_data = validation.reformate_external_data(data=external_model_data)

# align periods of gfpmpt data
period_data = validation.period_structure(data=data_model_intercomparison['Data'])
data_aligned = validation.align_period_data(data=data_filtered, period_data=period_data)

# convert units of gfpmpt
data_aligned = validation.add_world(data=data_aligned) 
data_aligned = validation.convert_unit(data=data_aligned)
data_aligned = validation.rename_parameter(data=data_aligned)

# merge data gfpmpt and external model data
data_fin = validation.merge_data(data=data_aligned, external_data=external_model_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13836/2187661390.py in <module>
#       8
#       9 # align periods of gfpmpt data
# ---> 10 period_data = validation.period_structure(data=data_model_intercomparison['Data'])
#      11 data_aligned = validation.align_period_data(data=data_filtered, period_data=period_data)
#      12
#
# KeyError: 'Data'

# %%
# plot interactive model intercomparison
model_intercomparison = interactiveModelComparison(data=data_fin, plot_option="min_max")
# Out:
# Dropdown(description='Select Region:', options=('Alle', 'Africa', 'Asia', 'Europe', 'Former Soviet Union', 'La…
# Dropdown(description='Select Model:', options=('Alle', 'GFPMpt', 'GFPM', 'GTM', 'GLOBIOM'), value='Alle')
# Dropdown(description='Select Parameter:', options=('Alle', 'Total Forest Non-soil C Stock (MtC)', 'CarbonStock…
# Dropdown(description='Select Scenario:', options=('Alle', 'SSP1', 'SSP2', 'SSP3', 'SSP4', 'SSP5'), value='Alle…
# Output()
# Output()

# %% [markdown]
# ### Worldmap

# %% [markdown]
# ### Heatmap

# %%
data_selection = data['data_periods']
heatmap_dropdown_instance = HeatmapDropDown(data=data_selection)
# Out:
# interactive(children=(Dropdown(description='Select Scenario:', options=('20240219_Updated_World_2008', '202402…
